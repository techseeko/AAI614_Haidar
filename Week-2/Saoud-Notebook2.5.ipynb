# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.5: Practice with Parquet and File Types*
#
# <a href="https://colab.research.google.com/github/techseeko/AAI614_Haidar/blob/main/Week-2/Saoud-Notebook2.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
class Timer:
    def __enter__(self):
        self.start = time.perf_counter()
        return self

    def __exit__(self, *args):
        self.end = time.perf_counter()
        self.interval = self.end - self.start

# %% [markdown]
# ##### Read the Parqeut file and time it

# %%
with Timer() as t_pd:
    df = pd.read_parquet('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.parquet')
print(t_pd.interval)
# Out:
# 0.3458720830000175

# %% [markdown]
# #### Read the CSV file and time it

# %%
with Timer() as t_pd:
    df = pd.read_csv('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.csv')
print(t_pd.interval)
# Out:
# 0.16990985699999328

# %% [markdown]
# #### Read the ZIP file and time it

# %%
import zipfile
with Timer() as t_pd:
    df = pd.read_csv('https://raw.githubusercontent.com/harmanani/AAI614/main/Week%202/niaaa-report.zip', compression="zip")
print(t_pd.interval)
# Out:
# 0.1256091040000058
