# %% [markdown]
# <a href="https://colab.research.google.com/github/techseeko/AAI614_Haidar/blob/main/Week-3/week3_p_value_test_stat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats
import numpy as np

n = 1000
alpha = 0.05
xbar = -0.5 # Sample mean
mu = 0 # Population mean
s = 10 # Standard deviation

# Calculate the test statistic
test_stat = (xbar - mu) / (s / np.sqrt(n))

# Calculate p-value for two-tailed test
pval = stats.norm.cdf(test_stat) * 2

print('test-stat:', round(test_stat, 4))
print('p-value (two-tailed):', round(pval, 4))
# Out:
# test-stat: -1.5811
# p-value (two-tailed): 0.1138
